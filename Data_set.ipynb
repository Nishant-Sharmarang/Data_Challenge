# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie = pd.read_excel(r"C:\Users\Nishant Sharma\Desktop\Work\Data Science Case Study\Data Science Case Study\movie_metadata.xls")

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
print(movie.columns.values)
# Out:
# ['color' 'director_name' 'num_critic_for_reviews' 'duration'
#  'director_facebook_likes' 'actor_3_facebook_likes' 'actor_2_name'
#  'actor_1_facebook_likes' 'gross' 'genres' 'actor_1_name' 'movie_title'
#  'num_voted_users' 'cast_total_facebook_likes' 'actor_3_name'
#  'facenumber_in_poster' 'plot_keywords' 'movie_movie_link'
#  'num_user_for_reviews' 'language' 'country' 'content_rating' 'budget'
#  'title_year' 'actor_2_facebook_likes' 'movie_score' 'aspect_ratio'
#  'movie_facebook_likes']

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
sns.heatmap(movie.isnull(), cbar=False)

# %%
import missingno as msno

# %%
msno.matrix(movie)

# %%
movie.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_movie_link               0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# movie_score                    0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
((movie.isnull().sum() )/ 5043)*100
# Out:
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_movie_link              0.000000
# num_user_for_reviews          0.416419
# language                      0.237954
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# title_year                    2.141582
# ...

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie_numeric = movie[['num_critic_for_reviews','duration','director_facebook_likes','actor_3_facebook_likes',
'actor_1_facebook_likes',
'gross',
'num_voted_users',
'cast_total_facebook_likes',
'facenumber_in_poster',
'num_user_for_reviews',
'budget',
'title_year',
'actor_2_facebook_likes',
'aspect_ratio',
'movie_facebook_likes']]

# %%
movie_numeric_with_ratings = movie[['num_critic_for_reviews','duration','director_facebook_likes','actor_3_facebook_likes',
'actor_1_facebook_likes',
'gross',
'num_voted_users',
'cast_total_facebook_likes',
'facenumber_in_poster',
'num_user_for_reviews',
'budget',
'title_year',
'actor_2_facebook_likes',
'movie_score',
'aspect_ratio',
'movie_facebook_likes']]

# %%
movie_numeric['Profit'] = movie_numeric['gross'] - movie_numeric['budget']
movie_numeric_with_ratings['Profit'] = movie_numeric_with_ratings['gross'] - movie_numeric_with_ratings['budget']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
movie_numeric_with_ratings.head()
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                     NaN       NaN                    131.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                  1000.0  760505847.0
# 1                  1000.0                 40000.0  309404152.0
# 2                   161.0                 11000.0  200074175.0
# 3                 23000.0                 27000.0  448130642.0
# 4                     NaN                   131.0          NaN
#
#    num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# 0           886204                       4834                   0.0
# 1           471220                      48350                   0.0
# ...

# %%
((movie_numeric.isnull().sum() )/ 5043)*100
# Out:
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# facenumber_in_poster          0.257783
# num_user_for_reviews          0.416419
# budget                        9.756098
# title_year                    2.141582
# actor_2_facebook_likes        0.257783
# aspect_ratio                  6.523895
# movie_facebook_likes          0.000000
# Profit                       22.843546
# dtype: float64

# %%
movie_numeric = movie_numeric.dropna()
movie_numeric_with_ratings = movie_numeric_with_ratings.dropna()
sns.heatmap(movie_numeric.isnull(), cbar=False)

# %% [markdown]
# 17 percentage of gross values are missing we proceed with droping the NA values

# %% [markdown]
#                                                           EDA

# %%
sns.distplot(movie_numeric_with_ratings['movie_score'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
movie_numeric_with_ratings[movie_numeric_with_ratings['movie_score']>7.5].shape[0]
# Out:
# 547

# %% [markdown]
#                    So the movies can be considered as blockbusters if imdb rating is above 7.5

# %%
sns.distplot(movie_numeric_with_ratings['duration'])

# %%
movie_numeric_with_ratings[movie_numeric_with_ratings['Profit']>0].shape[0]
# Out:
# 2023

# %%
numeric_features=movie._get_numeric_data().columns.values.tolist()
numeric_features.pop(13)
# Out:
# 'movie_score'

# %%
sns.jointplot(x = movie_numeric_with_ratings['duration'],y=movie_numeric_with_ratings['movie_score'],data = movie_numeric_with_ratings)

# %%
for f in numeric_features:
    sns.jointplot(x = movie_numeric_with_ratings[f], y = movie_numeric_with_ratings['movie_score'], data=movie_numeric_with_ratings)

# %%
movie_numeric_with_ratings.boxplot(column='duration', by='movie_score', figsize=(20,15))

# %%
movie.boxplot(column='duration',by='content_rating',figsize=(20,15))

# %%
sns.set(style="darkgrid")
sns.countplot(x="color", data = movie)

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (12, 6))
sns.countplot(x="country", data = movie)
ax = plt.xticks(rotation=90)

# %%
sns.lmplot(x='title_year', y='movie_score', data=movie)

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (20, 15))
sns.countplot(x="title_year", data = movie)
ax = plt.xticks(rotation=90)

# %%
sns.set(style="darkgrid")
plt.figure(figsize = (20, 15))
sns.countplot(x="content_rating", data = movie)
ax = plt.xticks(rotation=90)

# %%
a=[]
for i in movie['genres']:
    for j in i.split('|'):
        a.append(j)
df = pd.DataFrame({'A':a})
B = df['A'].value_counts()

# %%
B[0:10]
# Out:
# Drama        2594
# Comedy       1872
# Thriller     1411
# Action       1153
# Romance      1107
# Adventure     923
# Crime         889
# Sci-Fi        616
# Fantasy       610
# Horror        565
# Name: A, dtype: int64

# %%
from wordcloud import WordCloud

# %%
text = B
wordcloud = WordCloud(
    width = 500,
    height = 300,
    background_color = 'black').generate(str(text))
fig = plt.figure(
    figsize = (10, 10),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
a=[]
for i in movie['genres']:
    for j in i.split('|'):
        a.append(j)
df = pd.DataFrame({'A':a})
B = df['A'].value_counts()

# %%
c=[]
for i in movie['plot_keywords'].dropna():
    
    for j in i.split('|'):
        c.append(j)
df = pd.DataFrame({'C':c})
D = df['C'].value_counts()
D[0:10]
# Out:
# love             198
# friend           166
# murder           161
# death            132
# police           126
# new york city     91
# high school       89
# alien             82
# school            73
# boy               72
# Name: C, dtype: int64

# %%
numeric_features
# Out:
# ['num_critic_for_reviews',
#  'duration',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_1_facebook_likes',
#  'gross',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'facenumber_in_poster',
#  'num_user_for_reviews',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'aspect_ratio',
#  'movie_facebook_likes']

# %%
import operator
from scipy.stats import pearsonr
correl={}
for f in numeric_features:
    correl[f]=pearsonr(movie_numeric[f], movie_numeric_with_ratings['movie_score'])
sorted_cor = sorted(correl.items(), key=operator.itemgetter(1), reverse=True)
print (sorted_cor)
# Out:
# [('num_voted_users', (0.4779173195224901, 3.3771578624299455e-216)), ('duration', (0.3661236941947873, 6.5856197117407805e-121)), ('num_critic_for_reviews', (0.3438807746706107, 5.68601390518927e-106)), ('num_user_for_reviews', (0.32252236916953203, 9.830232534612976e-93)), ('movie_facebook_likes', (0.2794777423110302, 3.752413115644412e-69)), ('gross', (0.21212439378801837, 6.343056625143783e-40)), ('director_facebook_likes', (0.19083814199116178, 1.6747896559383954e-32)), ('cast_total_facebook_likes', (0.10625870040684939, 5.115550937114392e-11)), ('actor_2_facebook_likes', (0.10206037814304847, 2.851285957656286e-10)), ('actor_1_facebook_likes', (0.09313142432512429, 8.799644730811866e-09)), ('actor_3_facebook_likes', (0.06497354024959454, 6.105818816560503e-05)), ('budget', (0.0290405711179928, 0.07342092529461265)), ('aspect_ratio', (0.028453719940971497, 0.07942810915031553)), ('facenumber_in_poster', (-0.06429246963481733, 7.29126112673271e-05)), ('title_year', (-0.12926516085
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def corrmap(features, title):
    sns.set(context="paper", font="monospace")
    corrmat = movie_numeric[features].corr()
    f, ax = plt.subplots(figsize=(12, 9))
# Draw the heatmap using seaborn
    sns.heatmap(corrmat, vmax=.8, square=True)
corrmap(numeric_features,"Correlation matrix for numeric features")

# %%
import scipy.stats as stats

stats.probplot(movie['movie_score'], dist="norm", plot=plt)
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(movie.corr(), annot = True,linewidth =0.5 )

# %%
modelling_data = movie[movie['movie_score']>7.5]

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie['Profit'] = movie['gross'] -movie['budget']
modelling_data=movie[movie['Profit']>2*5.844717e+06]

# %%
modelling_data.shape
# Out:
# (1398, 29)

# %%
modelling_data.isnull().sum()
# Out:
# color                        1
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       1
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 1
# facenumber_in_poster         4
# plot_keywords                0
# movie_movie_link             0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# movie_score                  0
# aspect_ratio                 2
# movie_facebook_likes         0
# Profit                       0
# dtype: int64

# %%
modelling_data_with_profit = modelling_data[['num_critic_for_reviews','duration','director_facebook_likes','actor_3_facebook_likes',
'actor_1_facebook_likes',
'num_voted_users',
'cast_total_facebook_likes',
'facenumber_in_poster',
'num_user_for_reviews',
'title_year',
'budget',                                            
'actor_2_facebook_likes',
'movie_score',
'aspect_ratio',
'movie_facebook_likes',
'Profit']]

# %%
modelling_data_without_profit = modelling_data[['num_critic_for_reviews','duration','director_facebook_likes',
'actor_3_facebook_likes',
'actor_1_facebook_likes',
'num_voted_users',
'cast_total_facebook_likes',
'facenumber_in_poster',
'num_user_for_reviews',
'title_year',
'budget', 
'actor_2_facebook_likes',
'movie_score',
'aspect_ratio',
'movie_facebook_likes']]

# %%
modelling_data_without_profit.shape
# Out:
# (1398, 15)

# %%
(modelling_data_with_profit.isnull().sum()/len(modelling_data_without_profit))*100
# Out:
# num_critic_for_reviews       0.000000
# duration                     0.000000
# director_facebook_likes      0.000000
# actor_3_facebook_likes       0.071531
# actor_1_facebook_likes       0.000000
# num_voted_users              0.000000
# cast_total_facebook_likes    0.000000
# facenumber_in_poster         0.286123
# num_user_for_reviews         0.000000
# title_year                   0.000000
# budget                       0.000000
# actor_2_facebook_likes       0.000000
# movie_score                  0.000000
# aspect_ratio                 0.143062
# movie_facebook_likes         0.000000
# Profit                       0.000000
# dtype: float64

# %%
(modelling_data_without_profit.isnull().sum()/len(modelling_data_without_profit))*100
# Out:
# num_critic_for_reviews       0.000000
# duration                     0.000000
# director_facebook_likes      0.000000
# actor_3_facebook_likes       0.071531
# actor_1_facebook_likes       0.000000
# num_voted_users              0.000000
# cast_total_facebook_likes    0.000000
# facenumber_in_poster         0.286123
# num_user_for_reviews         0.000000
# title_year                   0.000000
# budget                       0.000000
# actor_2_facebook_likes       0.000000
# movie_score                  0.000000
# aspect_ratio                 0.143062
# movie_facebook_likes         0.000000
# dtype: float64

# %%
sns.heatmap(modelling_data_without_profit.isnull(), cbar=False)

# %%
modelling_data_with_profit = modelling_data_with_profit.dropna()
modelling_data_without_profit = modelling_data_without_profit.dropna()

# %%
sns.heatmap(modelling_data_without_profit.isnull(), cbar=False)

# %%
type(modelling_data_without_profit)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
X = modelling_data_without_profit
y = modelling_data_with_profit['Profit']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)

# %%
X.shape
# Out:
# (1391, 15)

# %%
y.shape
# Out:
# (1391,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
reg = LinearRegression()
reg.fit(X_train, y_train)
y_predicted = reg.predict(X_test)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_predicted))
print('R²: %.2f' % r2_score(y_true=y_test, y_pred=y_predicted))
# Out:
# Mean squared error: 3264887701245671.50
# R²: 0.31

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
regressor = RandomForestRegressor(n_estimators=500, random_state=0)  
regressor.fit(X_train, y_train)  
y_pred = regressor.predict(X_test)

# %%
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print('R²: %.2f' % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 3196951496126335.00
# R²: 0.32

# %%
print ("Features sorted by their score:")
print (sorted(zip(map(lambda x: round(x, 4), regressor.feature_importances_),modelling_data_without_profit ), 
             reverse=True))
# Out:
# Features sorted by their score:
# [(0.2856, 'num_voted_users'), (0.1122, 'num_user_for_reviews'), (0.0725, 'title_year'), (0.0716, 'budget'), (0.0601, 'num_critic_for_reviews'), (0.0527, 'movie_score'), (0.0526, 'movie_facebook_likes'), (0.0516, 'duration'), (0.0502, 'cast_total_facebook_likes'), (0.0446, 'actor_3_facebook_likes'), (0.0394, 'director_facebook_likes'), (0.037, 'actor_1_facebook_likes'), (0.0344, 'actor_2_facebook_likes'), (0.0189, 'facenumber_in_poster'), (0.0166, 'aspect_ratio')]

# %%
plt.figure(figsize=(20,15))
sns.heatmap(modelling_data_with_profit.corr(), annot = True,linewidth =0.5)
